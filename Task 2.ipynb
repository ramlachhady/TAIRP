# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("IPL_Players_Data(2008-2022).csv") 
dataset
# Out:
#       Unnamed: 0               Playerss  Year  Matches  Runss Average  \
# 0              0            Jos Buttler  2022       17    863   57.53
# 1              1              K L Rahul  2022       15    616   51.33
# 2              2        Quinton De Kock  2022       15    508   36.29
# 3              3          Hardik Pandya  2022       15    487   44.27
# 4              4           Shubman Gill  2022       16    483   34.50
# ...          ...                    ...   ...      ...    ...     ...
# 2170        2170  Paidikalva Vijaykumar  2008        9      1    0.00
# 2171        2171           Abdur Razzak  2008        1      0    0.00
# 2172        2172         Abhinav Mukund  2008        2      0    0.00
# 2173        2173    Lakshmipathy Balaji  2008        9      0    0.00
# 2174        2174            Munaf Patel  2008       15      0    0.00
#
#      Higest_score  Strike Rate  NO  Fifty  Four  Six
# 0             116       149.05   2      4    83   45
# ...

# %%
dataset.head()
# Out:
#    Unnamed: 0         Playerss  Year  Matches  Runss Average Higest_score  \
# 0           0      Jos Buttler  2022       17    863   57.53          116
# 1           1        K L Rahul  2022       15    616   51.33         103*
# 2           2  Quinton De Kock  2022       15    508   36.29         140*
# 3           3    Hardik Pandya  2022       15    487   44.27          87*
# 4           4     Shubman Gill  2022       16    483   34.50           96
#
#    Strike Rate  NO  Fifty  Four  Six
# 0       149.05   2      4    83   45
# 1       135.38   3      4    45   30
# 2       148.97   1      3    47   23
# 3       131.26   4      4    49   12
# 4       132.32   2      4    51   11

# %%
print(dataset.isnull().sum())
dataset.dropna(inplace=True)
# Out:
# Unnamed: 0      0
# Playerss        0
# Year            0
# Matches         0
# Runss           0
# Average         0
# Higest_score    0
# Strike Rate     0
# NO              0
# Fifty           0
# Four            0
# Six             0
# dtype: int64

# %%
numeric_columns = ['Year', 'Matches', 'Runss', 'Average', 'Strike Rate', 'NO', 'Fifty', 'Four', 'Six']
dataset[numeric_columns] = dataset[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
dataset['Average'] = dataset['Average'].astype(float)

# %%
dataset['Higest_score'] = pd.to_numeric(dataset['Higest_score'], errors='coerce')
dataset['Century'] = dataset['Higest_score'].apply(lambda x: 1 if x >= 100 else 0)

# %%
scaler = MinMaxScaler()
scaled_columns = ['Runss', 'Average', 'Strike Rate']
dataset[scaled_columns] = scaler.fit_transform(dataset[scaled_columns])

# %% [markdown]
# Visualization of player performance

# %%
jos_buttler_data = dataset[dataset['Playerss'] == 'Virat Kohli']
plt.figure(figsize=(10, 6))
plt.plot(jos_buttler_data['Year'], jos_buttler_data['Runss'], marker='o')
plt.title("Jos Buttler's Runs Over Years")
plt.xlabel('Year')
plt.ylabel('Runs')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
metrics = ['Matches', 'Fifty', 'Four', 'Six']
values = jos_buttler_data[metrics].iloc[0]  
plt.bar(metrics, values)
plt.title("Jos Buttler's Performance Metrics")
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.grid(True)
plt.show()

# %%
jos_buttler_data = dataset[dataset['Playerss'] == 'Jos Buttler']
plt.figure(figsize=(10, 6))
plt.plot(jos_buttler_data['Year'], jos_buttler_data['Runss'], marker='o')
plt.title("Jos Buttler's Runs Over Years")
plt.xlabel('Year')
plt.ylabel('Runs')
plt.grid(True)
plt.show()
plt.figure(figsize=(10, 6))
metrics = ['Matches', 'Fifty', 'Four', 'Six']
values = jos_buttler_data[metrics].iloc[0] 
plt.bar(metrics, values)
plt.title("Jos Buttler's Performance Metrics")
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.grid(True)
plt.show()
plt.figure(figsize=(10, 6))
plt.boxplot(jos_buttler_data['Runss'])
plt.title("Jos Buttler's Runs Distribution")
plt.ylabel('Runs')
plt.grid(True)
plt.show()
